# %% [markdown]
# # <font color='blue'>Projeto de Estratégias de Limpeza e Pré-Processamento de dados com linguagem python</font>
# ## <font color='blue'>Análise de Dados de Telecomunicações</font>
# ## <font color='blue'>Pré-Processamento de Dados</font>

# %% [markdown]
# ### <font color='blue'>Importando as bibliotecas</font>

# %%
# Biblioteca de calculos matemáticos
import math 
# Biblioteca para manipular o Sistema Operacional
import sys, os 
# Biblioteca para manipular dados
import numpy as np 
import pandas as pd

# %% [markdown]
# ### <font color='blue'>Carregando os Dados</font>

# %%
# Criando uma lista para identificar valores ausentes
lista_labels_valores_ausentes= ["n/a", "na", "undefined"]
# Carregando os dados 
df=pd.read_csv("dataset.csv", na_values=lista_labels_valores_ausentes)
# Verificando o numero de linhas e colunas
df.shape
# Verificando uma amostra do nosso Dataframe
df.head(10)
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# 5  1.311448e+19  4/12/2019 21:37     439.0   4/25/2019 8:08   553.0
# 6  1.311448e+19   4/13/2019 8:41     612.0   4/25/2019 8:16   168.0
# 7  1.304243e+19   4/14/2019 2:11     592.0   4/25/2019 2:26   512.0
# 8  1.311448e+19  4/14/2019 12:48     121.0  4/25/2019 10:22   960.0
# 9  1.304243e+19   4/15/2019 0:32       0.0   4/25/2019 0:40   284.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# ...

# %%
# Verificando numeros de linhas e colunas
df.shape
# Out:
# (150001, 55)

# %%
# Visualizando as ultimas linhas do meu dataframe
df.tail()
# Out:
#            Bearer Id           Start  Start ms              End  End ms  \
# 149996  7.277826e+18  4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18  4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19  4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19  4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             NaN       NaN              NaN     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 149996    81230.0  2.082022e+14   3.365069e+10  3.548311e+13
# 149997    97970.0  2.082019e+14   3.366345e+10  3.566051e+13
# 149998    98249.0  2.082017e+14   3.362189e+10  3.572121e+13
# 149999    97910.0  2.082021e+14   3.361962e+10  8.618620e+13
# 150000        NaN           NaN            NaN           NaN
#
#        Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 149996            D20434A  ...        1.619167e+07        1.176343e+07
# ...

# %%
# Carregando o dicionário de dados
dicionario=pd.read_excel("Dicionario.xlsx")
# Verificando uma amostra do nosso dicionario de dados
dicionario.head()
# Out:
#       Fields                                        Description
# 0  bearer id                             xDr session identifier
# 1  Dur. (ms)                  Total Duration of the xDR (in ms)
# 2      Start      Start time of the xDR (first frame timestamp)
# 3   Start ms  Milliseconds offset of start time for the xDR ...
# 4        End         End time of the xDR (last frame timestamp)

# %%
# Vendo os tipos das variaveis 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 149010 non-null  float64
#  1   Start                                     150000 non-null  object
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  object
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
# ...

# %% [markdown]
# ## <font color='blue'>Análise Exploratória</font>

# %%
# Descrevendo minhas variaveis numericas 
df.describe()
# Out:
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.490100e+05  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082016e+14
# std    2.893173e+18     288.611834     288.097653  8.103762e+04  2.148809e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.744050e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.324302e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.494290e+05    122172.000000    122189.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# ...

# %% [markdown]
# Existem 150.001 linhas e 55 colunas no dataframe. No entanto, temos 56 colunas com seus nomes e descrições no dicionário. Isso significa que há uma coluna descrita, mas não incluída no dataframe.
#
# Vamos identificar qual é a coluna faltante.Comparando as colunas do meu DataFrame com as colunas do meu Dicionario de Dados

# %%
# Concatenando meus 2 Dataframes 
df_compara_colunas = pd.concat([pd.Series(df.columns.tolist()), 
                                dicionario['Fields']],
                               axis = 1)
# Renomeando as colunas
df_compara_colunas.rename(columns = {0: 'Coluna no Dataset', 'Fields': 'Coluna no Dicionario'}, 
                          inplace = True)
# Visualizando meu Dataframe 
display(df_compara_colunas)
# Out:
#                            Coluna no Dataset  \
# 0                                  Bearer Id
# 1                                      Start
# 2                                   Start ms
# 3                                        End
# 4                                     End ms
# 5                                  Dur. (ms)
# 6                                       IMSI
# 7                              MSISDN/Number
# 8                                       IMEI
# 9                         Last Location Name
# 10                           Avg RTT DL (ms)
# 11                           Avg RTT UL (ms)
# 12                   Avg Bearer TP DL (kbps)
# 13                   Avg Bearer TP UL (kbps)
# 14               TCP DL Retrans. Vol (Bytes)
# 15               TCP UL Retrans. Vol (Bytes)
# 16                       DL TP < 50 Kbps (%)
# 17            50 Kbps < DL TP < 250 Kbps (%)
# 18             250 Kbps < DL TP < 1 Mbps (%)
# 19                        DL TP > 1 Mbps (%)
# ...

# %% [markdown]
# `Dur. (Ms)` é ignorado no dataset como visto no índice 1 em **df_compara_colunas**. É aqui que a ordem das colunas começou a mudar.
#
# Mas o mesmo nome de coluna `Dur. (Ms)` aparece no dataset no índice 5, enquanto o arquivo de dicionário nos diz que é `Dur. (S)` no índice 6. Como as medidas de ambas as colunas diferem conforme mostrado em seus nomes, nós precisamos verificar qual está certo. Para investigar isso, usaremos a coluna `Dur. (Ms) .1` que se encontra nos índices 28 e 29 no dataset e no arquivo de dicionário, respectivamente.

# %%
# Selecionando as duas colunas que iremos analisar 
df[['Dur. (ms)', 'Dur. (ms).1']]
# Out:
#         Dur. (ms)   Dur. (ms).1
# 0       1823652.0  1.823653e+09
# 1       1365104.0  1.365104e+09
# 2       1361762.0  1.361763e+09
# 3       1321509.0  1.321510e+09
# 4       1089009.0  1.089009e+09
# ...           ...           ...
# 149996    81230.0  8.123076e+07
# 149997    97970.0  9.797070e+07
# 149998    98249.0  9.824953e+07
# 149999    97910.0  9.791063e+07
# 150000        NaN           NaN
#
# [150001 rows x 2 columns]

# %% [markdown]
# Parece que a coluna `Dur. (Ms)` é medida em segundos. Portanto, vamos renomeá-la apropriadamente.
#
# Vamos também renomear algumas das colunas para que fiquem claras como sua descrição e sigam o estilo de nomenclatura de outras colunas.

# %%
# Renomeando colunas
df.rename(columns = {'Dur. (ms)': 'Dur (s)', 
                          'Dur. (ms).1': 'Dur (ms)', 
                          'Start ms': 'Start Offset (ms)', 
                          'End ms': 'End Offset (ms)'}, 
               inplace = True)
# Avaliando 
df.head(10)
# Out:
#       Bearer Id            Start  Start Offset (ms)              End  \
# 0  1.311448e+19   4/4/2019 12:01              770.0  4/25/2019 14:35
# 1  1.311448e+19   4/9/2019 13:04              235.0   4/25/2019 8:15
# 2  1.311448e+19   4/9/2019 17:42                1.0  4/25/2019 11:58
# 3  1.311448e+19   4/10/2019 0:31              486.0   4/25/2019 7:36
# 4  1.311448e+19  4/12/2019 20:10              565.0  4/25/2019 10:40
# 5  1.311448e+19  4/12/2019 21:37              439.0   4/25/2019 8:08
# 6  1.311448e+19   4/13/2019 8:41              612.0   4/25/2019 8:16
# 7  1.304243e+19   4/14/2019 2:11              592.0   4/25/2019 2:26
# 8  1.311448e+19  4/14/2019 12:48              121.0  4/25/2019 10:22
# 9  1.304243e+19   4/15/2019 0:32                0.0   4/25/2019 0:40
#
#    End Offset (ms)    Dur (s)          IMSI  MSISDN/Number          IMEI  \
# 0            662.0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# ...

# %% [markdown]
# ## <font color='blue'>Limpeza dos Dados</font>

# %% [markdown]
# ## Estratégia de Limpeza 1 - Tratamento de Valores Ausentes

# %% [markdown]
#     Tecnicas a serem aplicadas
# - 1- Identificando  Valores Ausentes
# - 2- Drop de Colunas com mais de 30% de valores ausentes
# - 3- Imputação com Preenchimento Reverso (BFILL)
# - 4- Imputação com Preenchimento Progressivo (FFILL)
# - 5- Imputação de Variáveis Categóricas
# - 6- Drop de Linhas com um % baixo

# %%
# Criando uma fuction para identificar o percentual de valores ausentes 
# Calcula o percentual de valores ausentes em todo o meu DataFrame
def func_calc_percentual_valores_ausentes(df):
    totalCells = np.product(df.shape)
    missingCount = df.isnull().sum()
    totalMissing = missingCount.sum()
    print("O dataset tem", round(((totalMissing/totalCells) * 100), 2), "%", "de valores ausentes.")

# %%
func_calc_percentual_valores_ausentes(df)
# Out:
# O dataset tem 12.72 % de valores ausentes.

# %% [markdown]
# Esta função irá indentificar os valoes nulos (NaN) , não necessariamente os valores ausentes, visto que, valor ausente é a ausência de INFORMAÇÃO , não de dados.

# %%
# Calculando o total de valores ausentes e o percentual por variável e colocando em um Dataset
# Função para calcular valores ausentes por coluna
def func_calc_percentual_valores_ausentes_coluna(df):
    # Total de valores ausentes
    mis_val = df.isnull().sum()
    # Porcentagem de valores ausentes
    mis_val_percent = 100 * mis_val / len(df)
    # Tipo de dado das colunas com valores ausentes
    mis_val_dtype = df.dtypes
    # Cria uma tabela com os resultados
    mis_val_table = pd.concat([mis_val, mis_val_percent, mis_val_dtype], axis=1)
    # Renomear as colunas
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'Valores Ausentes', 1 : '% de Valores Ausentes', 2: 'Dtype'})
    # Classifica a tabela por porcentagem de valores ausentes de forma decrescente e remove colunas sem valores faltantes
    mis_val_table_ren_columns = mis_val_table_ren_columns[mis_val_table_ren_columns.iloc[:,0] != 0].sort_values('% de Valores Ausentes', ascending = False).round(2)
    # Print 
    print ("O dataset tem " + str(df.shape[1]) + " colunas.\n"
        "Encontrado: " + str(mis_val_table_ren_columns.shape[0]) + " colunas que têm valores ausentes.")
    if mis_val_table_ren_columns.shape[0] == 0:
        return
    # Retorna o dataframe com informações ausentes
    return mis_val_table_ren_columns

# %%
func_calc_percentual_valores_ausentes(df)
df_missing = func_calc_percentual_valores_ausentes_coluna(df)
# Visualizando o Dataframe
df_missing
# Out:
# O dataset tem 12.72 % de valores ausentes.
# O dataset tem 55 colunas.
# Encontrado: 41 colunas que têm valores ausentes.
#                                           Valores Ausentes  \
# Nb of sec with 37500B < Vol UL                      130254
# Nb of sec with 6250B < Vol UL < 37500B              111843
# Nb of sec with 125000B < Vol DL                      97538
# TCP UL Retrans. Vol (Bytes)                          96649
# Nb of sec with 31250B < Vol DL < 125000B             93586
# Nb of sec with 1250B < Vol UL < 6250B                92894
# Nb of sec with 6250B < Vol DL < 31250B               88317
# TCP DL Retrans. Vol (Bytes)                          88146
# HTTP UL (Bytes)                                      81810
# HTTP DL (Bytes)                                      81474
# Avg RTT DL (ms)                                      27829
# Avg RTT UL (ms)                                      27812
# Handset Manufacturer                                  9559
# ...

# %% [markdown]
# -Iremos utilizar um conceito quando se trata de % de valores ausentes
#
# -Removeremos as colunas que tem mais de 30% de valores ausentes

# %%
# Fazendo uma lista das colunas que serão removidas
lista=df_missing[df_missing['% de Valores Ausentes']>=30.0].index.tolist()

# %%
# Colunas que serão removidas
colunas_para_remover = [col for col in lista if col not in ['TCP UL Retrans. Vol (Bytes)',
    'TCP DL Retrans. Vol (Bytes)']]
# Visualizando a lista
colunas_para_remover
# Out:
# ['Nb of sec with 37500B < Vol UL',
#  'Nb of sec with 6250B < Vol UL < 37500B',
#  'Nb of sec with 125000B < Vol DL',
#  'Nb of sec with 31250B < Vol DL < 125000B',
#  'Nb of sec with 1250B < Vol UL < 6250B',
#  'Nb of sec with 6250B < Vol DL < 31250B',
#  'HTTP UL (Bytes)',
#  'HTTP DL (Bytes)']

# %% [markdown]
# Mesmo que as variáveis `TCP DL Retrans. Vol (Bytes)` e `TCP UL Retrans. Vol (Bytes)` tenham muitos valores ausentes, em vez de removê-las, iremos imputá-las, uma vez que elas podem ser necessárias para nossa análise posterior.

# %%
# Criando um novo Dataset 
df_limpo=df.drop(colunas_para_remover,axis=1)
# Visualizando o Dataset 
df_limpo
# Out:
#            Bearer Id            Start  Start Offset (ms)              End  \
# 0       1.311448e+19   4/4/2019 12:01              770.0  4/25/2019 14:35
# 1       1.311448e+19   4/9/2019 13:04              235.0   4/25/2019 8:15
# 2       1.311448e+19   4/9/2019 17:42                1.0  4/25/2019 11:58
# 3       1.311448e+19   4/10/2019 0:31              486.0   4/25/2019 7:36
# 4       1.311448e+19  4/12/2019 20:10              565.0  4/25/2019 10:40
# ...              ...              ...                ...              ...
# 149996  7.277826e+18   4/29/2019 7:28              451.0   4/30/2019 6:02
# 149997  7.349883e+18   4/29/2019 7:28              483.0  4/30/2019 10:41
# 149998  1.311448e+19   4/29/2019 7:28              283.0  4/30/2019 10:46
# 149999  1.311448e+19   4/29/2019 7:28              696.0  4/30/2019 10:40
# 150000           NaN              NaN                NaN              NaN
#
#         End Offset (ms)    Dur (s)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
# Avaliacao 
func_calc_percentual_valores_ausentes(df_limpo)
func_calc_percentual_valores_ausentes_coluna(df_limpo)
# Out:
# O dataset tem 3.85 % de valores ausentes.
# O dataset tem 47 colunas.
# Encontrado: 33 colunas que têm valores ausentes.
#                                 Valores Ausentes  % de Valores Ausentes  \
# TCP UL Retrans. Vol (Bytes)                96649                  64.43
# TCP DL Retrans. Vol (Bytes)                88146                  58.76
# Avg RTT DL (ms)                            27829                  18.55
# Avg RTT UL (ms)                            27812                  18.54
# Handset Type                                9559                   6.37
# Handset Manufacturer                        9559                   6.37
# Last Location Name                          1153                   0.77
# MSISDN/Number                               1066                   0.71
# Bearer Id                                    991                   0.66
# Nb of sec with Vol UL < 1250B                793                   0.53
# ...

# %% [markdown]
# Uma vez que as porcentagens ausentes de `'TCP UL Retrans. Vol (Bytes)` e `TCP DL Retrans. Vol (Bytes)`são muito altos, iremos imputá-los com o método de preenchimento reverso usando o método Bfill.

# %% [markdown]
#  method = 'bfill': Bfill ou backward-fill propaga o primeiro valor não nulo observado para trás até que outro valor não nulo seja encontrado

# %%
# Fazendo o preenchimento reverso 
# Imputação de valores ausentes usando backward fill
def fix_missing_bfill(df, col):
    count = df[col].isna().sum()
    df[col] = df[col].fillna(method = 'bfill')
    print(f"{count} valores ausentes na coluna {col} foram substituídos usando o método de preenchimento reverso.")
    return df[col]

# %%
# Aplicando o método backward fill
fix_missing_bfill(df_limpo, 'TCP UL Retrans. Vol (Bytes)')
fix_missing_bfill(df_limpo,'TCP DL Retrans. Vol (Bytes)' )
# Out:
# 96649 valores ausentes na coluna TCP UL Retrans. Vol (Bytes) foram substituídos usando o método de preenchimento reverso.
# 88146 valores ausentes na coluna TCP DL Retrans. Vol (Bytes) foram substituídos usando o método de preenchimento reverso.
# 0         19520.0
# 1         19520.0
# 2         19520.0
# 3         19520.0
# 4         19520.0
#            ...
# 149996        NaN
# 149997        NaN
# 149998        NaN
# 149999        NaN
# 150000        NaN
# Name: TCP DL Retrans. Vol (Bytes), Length: 150001, dtype: float64

# %%
# Avaliacao 
func_calc_percentual_valores_ausentes(df_limpo)
func_calc_percentual_valores_ausentes_coluna(df_limpo)
# Out:
# O dataset tem 1.23 % de valores ausentes.
# O dataset tem 47 colunas.
# Encontrado: 33 colunas que têm valores ausentes.
#                                 Valores Ausentes  % de Valores Ausentes  \
# Avg RTT DL (ms)                            27829                  18.55
# Avg RTT UL (ms)                            27812                  18.54
# Handset Type                                9559                   6.37
# Handset Manufacturer                        9559                   6.37
# Last Location Name                          1153                   0.77
# MSISDN/Number                               1066                   0.71
# Bearer Id                                    991                   0.66
# Nb of sec with Vol UL < 1250B                793                   0.53
# UL TP > 300 Kbps (%)                         792                   0.53
# 50 Kbps < UL TP < 300 Kbps (%)               792                   0.53
# ...

# %% [markdown]
# Já `Avg RTT DL (ms)` e `Avg RTT UL (ms)` têm as próximas porcentagens mais altas de valores ausentes com cerca de 18,5% cada. Vamos verificar se as variáveis estão enviesadas (não seguem uma distribuição normal).A partir daí vejo se posso substituir as valores ausentes pela media ou mediana

# %%
# Calculando a assimetria 
print(" A Avg RTT DL(ms): {}".format(df_limpo['Avg RTT DL (ms)'].skew(skipna = True)))
print(" A Avg RTT UL(ms): {}".format(df_limpo['Avg RTT UL (ms)'].skew(skipna = True)))
# Out:
#  A Avg RTT DL(ms): 62.90782807995961
#  A Avg RTT UL(ms): 28.45741458546382

# %% [markdown]
# Interpretamos a assimetria assim:
#
#     - Se a assimetria estiver entre -0,5 e 0,5 os dados são bastante simétricos
#     - Se a assimetria estiver entre -1 e - 0,5 ou entre 0,5 e 1, os dados estão               moderadamente inclinados
#     - Se a assimetria for menor que -1 ou maior que 1, os dados estão altamente enviesados

# %% [markdown]
# Vimos que minhas duas variaveis não seguem uma distribuição normal ( Estão bastante enviesados ) então aplicaremos o método de preechimento progressivo  usando o método Ffill.

# %% [markdown]
# method = 'ffill': Ffill ou forward-fill propaga o último valor não nulo observado para frente até que outro valor não nulo seja encontrado

# %%
# Fazendo o preechimento progressivo
# Imputação de valores ausentes usando forward fill 
def fix_missing_ffill(df, col):
    count = df[col].isna().sum()
    df[col] = df[col].fillna(method = 'ffill')
    print(f"{count} valores ausentes na coluna {col} foram substituídos usando o método de preenchimento progressivo.")
    return df[col]

# %%
fix_missing_ffill(df_limpo,'Avg RTT DL (ms)')
fix_missing_ffill(df_limpo,'Avg RTT UL (ms)')
# Out:
# 27829 valores ausentes na coluna Avg RTT DL (ms) foram substituídos usando o método de preenchimento progressivo.
# 27812 valores ausentes na coluna Avg RTT UL (ms) foram substituídos usando o método de preenchimento progressivo.
# 0         5.0
# 1         5.0
# 2         5.0
# 3         5.0
# 4         5.0
#          ...
# 149996    0.0
# 149997    2.0
# 149998    6.0
# 149999    5.0
# 150000    5.0
# Name: Avg RTT UL (ms), Length: 150001, dtype: float64

# %%
# Avaliacao 
func_calc_percentual_valores_ausentes(df_limpo)
func_calc_percentual_valores_ausentes_coluna(df_limpo)
# Out:
# O dataset tem 0.44 % de valores ausentes.
# O dataset tem 47 colunas.
# Encontrado: 31 colunas que têm valores ausentes.
#                                 Valores Ausentes  % de Valores Ausentes  \
# Handset Type                                9559                   6.37
# Handset Manufacturer                        9559                   6.37
# Last Location Name                          1153                   0.77
# MSISDN/Number                               1066                   0.71
# Bearer Id                                    991                   0.66
# Nb of sec with Vol UL < 1250B                793                   0.53
# UL TP > 300 Kbps (%)                         792                   0.53
# 50 Kbps < UL TP < 300 Kbps (%)               792                   0.53
# 10 Kbps < UL TP < 50 Kbps (%)                792                   0.53
# UL TP < 10 Kbps (%)                          792                   0.53
# ...

# %% [markdown]
# Visto que `Handset Type` e `Handset Manufacturer` são colunas categóricas, é melhor imputá-los com o valor "unknown" para que não enviesemos os dados.

# %%
# Preenche valor NA
def fix_missing_value(df, col, value):
    count = df[col].isna().sum()
    df[col] = df[col].fillna(value)
    if type(value) == 'str':
        print(f"{count} valores ausentes na coluna {col} foram substituídos por '{value}'.")
    else:
        print(f"{count} valores ausentes na coluna {col} foram substituídos por {value}.")
    return df[col]

# %%
fix_missing_value(df_limpo,'Handset Type','unknown')
fix_missing_value(df_limpo,"Handset Manufacturer" ,'unknown')
# Out:
# 9559 valores ausentes na coluna Handset Type foram substituídos por unknown.
# 9559 valores ausentes na coluna Handset Manufacturer foram substituídos por unknown.
# 0         Samsung
# 1         Samsung
# 2         Samsung
# 3         unknown
# 4         Samsung
#            ...
# 149996      Apple
# 149997      Apple
# 149998      Apple
# 149999     Huawei
# 150000    unknown
# Name: Handset Manufacturer, Length: 150001, dtype: object

# %%
# Avaliacao 
func_calc_percentual_valores_ausentes(df_limpo)
func_calc_percentual_valores_ausentes_coluna(df_limpo)
# Out:
# O dataset tem 0.17 % de valores ausentes.
# O dataset tem 47 colunas.
# Encontrado: 29 colunas que têm valores ausentes.
#                                 Valores Ausentes  % de Valores Ausentes  \
# Last Location Name                          1153                   0.77
# MSISDN/Number                               1066                   0.71
# Bearer Id                                    991                   0.66
# Nb of sec with Vol UL < 1250B                793                   0.53
# UL TP > 300 Kbps (%)                         792                   0.53
# 50 Kbps < UL TP < 300 Kbps (%)               792                   0.53
# 10 Kbps < UL TP < 50 Kbps (%)                792                   0.53
# UL TP < 10 Kbps (%)                          792                   0.53
# Nb of sec with Vol DL < 6250B                755                   0.50
# 50 Kbps < DL TP < 250 Kbps (%)               754                   0.50
# ...

# %% [markdown]
# Iremos remover os restos das minhas linhas ausentes,visto que o % é extremamente baixo

# %%
# Drop de linhas com valores ausentes
def drop_rows_with_missing_values(df):
    old = df.shape[0]
    df.dropna(inplace = True)
    new = df.shape[0]
    count = old - new
    print(f"{count} linhas contendo valores ausentes foram descartadas.")

# %%
# Executando a fuction
drop_rows_with_missing_values(df_limpo)
# Out:
# 3114 linhas contendo valores ausentes foram descartadas.

# %%
# Avaliacao 
func_calc_percentual_valores_ausentes(df_limpo)
func_calc_percentual_valores_ausentes_coluna(df_limpo)
df_limpo.shape
# Out:
# O dataset tem 0.0 % de valores ausentes.
# O dataset tem 47 colunas.
# Encontrado: 0 colunas que têm valores ausentes.
# (146887, 47)

# %% [markdown]
# ## Estratégia de Limpeza 2 - Conversão de Tipos de Dados

# %%
# Verificando como o pandas interpretou meu Dataframe
df_limpo.dtypes
# Out:
# Bearer Id                         float64
# Start                              object
# Start Offset (ms)                 float64
# End                                object
# End Offset (ms)                   float64
# Dur (s)                           float64
# IMSI                              float64
# MSISDN/Number                     float64
# IMEI                              float64
# Last Location Name                 object
# Avg RTT DL (ms)                   float64
# Avg RTT UL (ms)                   float64
# Avg Bearer TP DL (kbps)           float64
# Avg Bearer TP UL (kbps)           float64
# TCP DL Retrans. Vol (Bytes)       float64
# TCP UL Retrans. Vol (Bytes)       float64
# DL TP < 50 Kbps (%)               float64
# 50 Kbps < DL TP < 250 Kbps (%)    float64
# 250 Kbps < DL TP < 1 Mbps (%)     float64
# DL TP > 1 Mbps (%)                float64
# UL TP < 10 Kbps (%)               float64
# 10 Kbps < UL TP < 50 Kbps (%)     float64
# ...

# %%
# Visualizando uma amostra dos meus dados
df_limpo.head(10)
# Out:
#       Bearer Id            Start  Start Offset (ms)              End  \
# 0  1.311448e+19   4/4/2019 12:01              770.0  4/25/2019 14:35
# 1  1.311448e+19   4/9/2019 13:04              235.0   4/25/2019 8:15
# 2  1.311448e+19   4/9/2019 17:42                1.0  4/25/2019 11:58
# 3  1.311448e+19   4/10/2019 0:31              486.0   4/25/2019 7:36
# 4  1.311448e+19  4/12/2019 20:10              565.0  4/25/2019 10:40
# 5  1.311448e+19  4/12/2019 21:37              439.0   4/25/2019 8:08
# 6  1.311448e+19   4/13/2019 8:41              612.0   4/25/2019 8:16
# 7  1.304243e+19   4/14/2019 2:11              592.0   4/25/2019 2:26
# 8  1.311448e+19  4/14/2019 12:48              121.0  4/25/2019 10:22
# 9  1.304243e+19   4/15/2019 0:32                0.0   4/25/2019 0:40
#
#    End Offset (ms)    Dur (s)          IMSI  MSISDN/Number          IMEI  \
# 0            662.0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# ...

# %% [markdown]
# Observando as colunas, podemos perceber que as colunas `Start` e `End` são, na verdade, valores de data e hora, embora sejam rotuladas como objetos pelo pandas. Além dessas duas colunas, todas as outras colunas com tipos de dados de objeto são, na verdade, valores de string. Portanto, vamos converter essas colunas em seus tipos de dados apropriados.

# %%
# Criando uma funcao que converte a variável para o tipo de data 
def convert_to_datetime(df, columns):
    for col in columns:
        df[col] = pd.to_datetime(df[col])

# %%
# Executando a função
convert_to_datetime(df_limpo, ['Start', 'End'])

# %%
# Pegando minhas colunas com o tipo object
string_columns=df_limpo.select_dtypes(include='object').columns.tolist()
# Visualizando
string_columns
# Out:
# ['Last Location Name', 'Handset Manufacturer', 'Handset Type']

# %%
# Criar uma funcao que converte a variavel para o tipo de string
def convert_to_string(df, columns):
    for col in columns:
        df[col] = df[col].astype("string")

# %%
# Executando a funcao
convert_to_string(df_limpo, string_columns)

# %%
# Avalia
df_limpo.dtypes
# Out:
# Bearer Id                                float64
# Start                             datetime64[ns]
# Start Offset (ms)                        float64
# End                               datetime64[ns]
# End Offset (ms)                          float64
# Dur (s)                                  float64
# IMSI                                     float64
# MSISDN/Number                            float64
# IMEI                                     float64
# Last Location Name                        string
# Avg RTT DL (ms)                          float64
# Avg RTT UL (ms)                          float64
# Avg Bearer TP DL (kbps)                  float64
# Avg Bearer TP UL (kbps)                  float64
# TCP DL Retrans. Vol (Bytes)              float64
# TCP UL Retrans. Vol (Bytes)              float64
# DL TP < 50 Kbps (%)                      float64
# 50 Kbps < DL TP < 250 Kbps (%)           float64
# 250 Kbps < DL TP < 1 Mbps (%)            float64
# ...

# %% [markdown]
# Também sabemos que `Bearer Id`, `IMSI`, `MSISDN / Number`, `IMEI` são números únicos usados para identificação. Portanto, para melhor legibilidade (e facilitar os filtros usados mais frente), vamos alterá-los de float64 para int64.

# %%
# Lista de colunas para conversão
int_cols = ['Bearer Id', 'IMSI', 'MSISDN/Number', 'IMEI']
# Visualizando
int_cols
# Out:
# ['Bearer Id', 'IMSI', 'MSISDN/Number', 'IMEI']

# %%
# Criar uma funcao que converte a variavel para o tipo int
def convert_to_int(df, columns):
    for col in columns:
        df[col] = df[col].astype("int64")

# %%
# Executando a funcao
convert_to_int(df_limpo, int_cols)

# %%
# Avalia
df_limpo.dtypes
# Out:
# Bearer Id                                  int64
# Start                             datetime64[ns]
# Start Offset (ms)                        float64
# End                               datetime64[ns]
# End Offset (ms)                          float64
# Dur (s)                                  float64
# IMSI                                       int64
# MSISDN/Number                              int64
# IMEI                                       int64
# Last Location Name                        string
# Avg RTT DL (ms)                          float64
# Avg RTT UL (ms)                          float64
# Avg Bearer TP DL (kbps)                  float64
# Avg Bearer TP UL (kbps)                  float64
# TCP DL Retrans. Vol (Bytes)              float64
# TCP UL Retrans. Vol (Bytes)              float64
# DL TP < 50 Kbps (%)                      float64
# 50 Kbps < DL TP < 250 Kbps (%)           float64
# 250 Kbps < DL TP < 1 Mbps (%)            float64
# ...

# %% [markdown]
# ## Estratégia de Limpeza 3 - Tratar registro Duplicado

# %%
# Criando minha funcao
def drop_duplicates(df):
    old = df.shape[0]
    df.drop_duplicates(inplace = True)
    new = df.shape[0]
    count = old - new
    if (count == 0):
        print("Nenhuma linha duplicada foi encontrada.")
    else:
        print(f"{count} linhas duplicadas foram encontradas e removidas.")

# %%
drop_duplicates(df_limpo)
# Out:
# Nenhuma linha duplicada foi encontrada.

# %% [markdown]
# Vimos que não temos registro duplicados

# %% [markdown]
# ## Estratégia de Limpeza 4 - Engenharia de Atributos

# %% [markdown]
# Como vimos na seção de limpeza da coluna, temos duas colunas de duração, uma em segundos e a outra em microssegundos.Vamos manter apenas uma ( `Dur (ms)`)

# %%
# Drop de colunas
def drop_columns(df, columns):
    df.drop(columns, axis = 1, inplace = True)
    count = len(columns)
    if count == 1:
        print(f"{count} coluna foi descartada.")
    else:
        print(f"{count} colunas foram descartadas.")

# %%
# Executando a função
drop_columns(df_limpo, ['Dur (s)'])
# Out:
# 1 coluna foi descartada.

# %% [markdown]
# ## Estratégia de Limpeza 5 - Tratando Outliers

# %% [markdown]
# ![title](outliers.png)

# %% [markdown]
# Iremos usar esta estratégia para indentificar e tratar os valores outliers

# %%
# Criando uma funcao 
class TrataOutlier:

    # Construtor
    def __init__(self, df: pd.DataFrame) -> None:
        self.df = df

    def count_outliers(self, Q1, Q3, IQR, columns):
        cut_off = IQR * 1.5
        temp_df = (self.df[columns] < (Q1 - cut_off)) | (self.df[columns] > (Q3 + cut_off))
        return [len(temp_df[temp_df[col] == True]) for col in temp_df]

    def calc_skew(self, columns=None):
        if columns == None:
            columns = self.df.columns
        return [self.df[col].skew() for col in columns]

    def percentage(self, list):
        return [str(round(((value/150001) * 100), 2)) + '%' for value in list]

    def remove_outliers(self, columns):
        for col in columns:
            Q1, Q3 = self.df[col].quantile(0.25), self.df[col].quantile(0.75)
            IQR = Q3 - Q1
            cut_off = IQR * 1.5
            lower, upper = Q1 - cut_off, Q3 + cut_off
            self.df = self.df.drop(self.df[self.df[col] > upper].index)
            self.df = self.df.drop(self.df[self.df[col] < lower].index)

    def replace_outliers_with_fences(self, columns):
        for col in columns:
            Q1, Q3 = self.df[col].quantile(0.25), self.df[col].quantile(0.75)
            IQR = Q3 - Q1
            cut_off = IQR * 1.5
            lower, upper = Q1 - cut_off, Q3 + cut_off

            self.df[col] = np.where(self.df[col] > upper, upper, self.df[col])
            self.df[col] = np.where(self.df[col] < lower, lower, self.df[col])

    def getOverview(self, columns) -> None:
        min = self.df[columns].min()
        Q1 = self.df[columns].quantile(0.25)
        median = self.df[columns].quantile(0.5)
        Q3 = self.df[columns].quantile(0.75)
        max = self.df[columns].max()
        IQR = Q3 - Q1
        skew = self.calc_skew(columns)
        outliers = self.count_outliers(Q1, Q3, IQR, columns)
        cut_off = IQR * 1.5
        lower, upper = Q1 - cut_off, Q3 + cut_off

        new_columns = ['Nome de Coluna', 'Min', 'Q1', 'Median', 'Q3', 'Max', 'IQR', 'Lower fence', 'Upper fence', 'Skew', 'Num_Outliers', 'Percent_Outliers' ]
        
        data = zip([column for column in self.df[columns]], min, Q1, median, Q3, max, IQR, lower, upper, skew, outliers, self.percentage(outliers))

        new_df = pd.DataFrame(data = data, columns = new_columns)
        
        new_df.set_index('Nome de Coluna', inplace = True)
        \
        return new_df.sort_values('Num_Outliers', ascending = False).transpose()

# %%
# Cria o objeto que trata o outlier
trata_outlier=TrataOutlier(df_limpo)

# %%
# Criando uma lista com as variaveis float 
lista_colunas = df_limpo.select_dtypes('float64').columns.tolist()

# %%
# Visão geral dos outliers antes
trata_outlier.getOverview(lista_colunas)
# Out:
# Nome de Coluna   DL TP > 1 Mbps (%) 10 Kbps < UL TP < 50 Kbps (%)  \
# Min                             0.0                           0.0
# Q1                              0.0                           0.0
# Median                          0.0                           0.0
# Q3                              0.0                           0.0
# Max                            94.0                          98.0
# IQR                             0.0                           0.0
# Lower fence                     0.0                           0.0
# Upper fence                     0.0                           0.0
# Skew                       5.345557                     10.941071
# Num_Outliers                  36594                         31509
# Percent_Outliers              24.4%                        21.01%
#
# Nome de Coluna   250 Kbps < DL TP < 1 Mbps (%) Activity Duration DL (ms)  \
# Min                                        0.0                       0.0
# ...

# %%
# Replace dos outliers
trata_outlier.replace_outliers_with_fences(lista_colunas)

# %%
# Visão geral dos outliers depois 
trata_outlier.getOverview(lista_colunas)
# Out:
# Nome de Coluna   Start Offset (ms) Nb of sec with Vol DL < 6250B  \
# Min                            0.0                           1.0
# Q1                           250.0                          87.0
# Median                       499.0                         201.0
# Q3                           749.0                        2612.5
# Max                          999.0                       6400.75
# IQR                          499.0                        2525.5
# Lower fence                 -498.5                      -3701.25
# Upper fence                 1497.5                       6400.75
# Skew                      0.000823                      1.205814
# Num_Outliers                     0                             0
# Percent_Outliers              0.0%                          0.0%
#
# Nome de Coluna   Social Media DL (Bytes) Social Media UL (Bytes)  \
# Min                                 12.0                     0.0
# ...

# %% [markdown]
# ## Estratégia de Limpeza 6 - Transformação de Dados

# %% [markdown]
# Ter a soma dos volumes de dados de upload e download para cada aplicativo como um total pode ser necessário para análises futuras
#
# Então vamos concatenar as colunas

# %%
df_limpo['Social Media Data Volume (Bytes)'] = df_limpo['Social Media UL (Bytes)'] + df_limpo['Social Media DL (Bytes)']

# %%
df_limpo['Google Data Volume (Bytes)'] = df_limpo['Google UL (Bytes)'] + df_limpo['Google DL (Bytes)']

# %%
df_limpo['Email Data Volume (Bytes)'] = df_limpo['Email UL (Bytes)'] + df_limpo['Email DL (Bytes)']

# %%
df_limpo['Youtube Data Volume (Bytes)'] = df_limpo['Youtube UL (Bytes)'] + df_limpo['Youtube DL (Bytes)']

# %%
df_limpo['Netflix Data Volume (Bytes)'] = df_limpo['Netflix UL (Bytes)'] + df_limpo['Netflix DL (Bytes)']

# %%
df_limpo['Gaming Data Volume (Bytes)'] = df_limpo['Gaming UL (Bytes)'] + df_limpo['Gaming DL (Bytes)']

# %%
df_limpo['Other Data Volume (Bytes)'] = df_limpo['Other UL (Bytes)'] + df_limpo['Other DL (Bytes)']

# %%
df_limpo['Total Data Volume (Bytes)'] = df_limpo['Total UL (Bytes)'] + df_limpo['Total DL (Bytes)']

# %%
df_limpo.shape
# Out:
# (146887, 54)

# %% [markdown]
# ### <font color='blue'>Salvando os dados após a limpeza</font>

# %%
df_limpo.to_csv('Novo_dataset.csv')

# %% [markdown]
# ### <font color='blue'>FIM</font>
